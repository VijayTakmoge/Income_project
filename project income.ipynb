# %% [markdown]
# # Objective :
#     "Analysis of the people income as per what they do for leaving".

# %% [markdown]
# # Import Library and Dataset

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
# Read the data in
inc=pd.read_csv(r'C:\Users\Vijay\OneDrive\Documents\phytonpanda\income.csv')

# %%
inc.head(20)
# Out:
#     age            JobType         EdType        maritalstatus  \
# 0    45            Private        HS-grad             Divorced
# 1    24        Federal-gov        HS-grad        Never-married
# 2    44            Private   Some-college   Married-civ-spouse
# 3    27            Private            9th        Never-married
# 4    20            Private   Some-college        Never-married
# 5    44            Private        HS-grad              Widowed
# 6    51            Private        HS-grad   Married-civ-spouse
# 7    20            Private        HS-grad   Married-civ-spouse
# 8    17                  ?           11th        Never-married
# 9    19            Private        HS-grad        Never-married
# 10   45       Self-emp-inc   Some-college   Married-civ-spouse
# 11   60            Private        HS-grad   Married-civ-spouse
# 12   44   Self-emp-not-inc        HS-grad   Married-civ-spouse
# 13   40            Private      Assoc-voc   Married-civ-spouse
# ...

# %% [markdown]
# # Data Pre-Processing

# %%
inc.isnull().sum()[inc.isnull().sum()>0]
# Out:
# Series([], dtype: int64)

# %%
inc.JobType.value_counts()
import numpy as np

# %%
inc.replace({' ?':np.NaN},inplace=True)

# %%
inc.isnull().sum()[inc.isnull().sum()>0]
# Out:
# JobType       1809
# occupation    1816
# dtype: int64

# %%
inc.occupation.value_counts()
# Out:
#  Prof-specialty       4038
#  Craft-repair         4030
#  Exec-managerial      3992
#  Adm-clerical         3721
#  Sales                3584
#  Other-service        3212
#  Machine-op-inspct    1966
#  Transport-moving     1572
#  Handlers-cleaners    1350
#  Farming-fishing       989
#  Tech-support          912
#  Protective-serv       644
#  Priv-house-serv       143
#  Armed-Forces            9
# Name: occupation, dtype: int64

# %%
inc.JobType.fillna("Private",inplace=True)
inc.occupation.fillna('Prof-specialty',inplace=True)

# %%
inc.head()
# Out:
#    age       JobType         EdType        maritalstatus       occupation  \
# 0   45       Private        HS-grad             Divorced     Adm-clerical
# 1   24   Federal-gov        HS-grad        Never-married     Armed-Forces
# 2   44       Private   Some-college   Married-civ-spouse   Prof-specialty
# 3   27       Private            9th        Never-married     Craft-repair
# 4   20       Private   Some-college        Never-married            Sales
#
#       relationship    race   gender  capitalgain  capitalloss  hoursperweek  \
# 0    Not-in-family   White   Female            0            0            28
# 1        Own-child   White     Male            0            0            40
# 2          Husband   White     Male            0            0            40
# 3   Other-relative   White     Male            0            0            40
# 4    Not-in-family   White     Male            0            0            35
#
#     nativecountry                        SalStat
# ...

# %%
inc.JobType.value_counts()
# Out:
#  Private             22286
#  Self-emp-not-inc     2499
#  Local-gov            2067
# Private               1809
#  State-gov            1279
#  Self-emp-inc         1074
#  Federal-gov           943
#  Without-pay            14
#  Never-worked            7
# Name: JobType, dtype: int64

# %%
inc.EdType.replace({' Preschool': 1, '1st-4th': 2,' 5th-6th': 3,' 7th-8th': 4, ' 9th': 5, ' 10th': 6, ' 11th': 7,
                            ' 12th': 8, ' HS-grad': 9,  ' Some-college': 10, ' Assoc-acdm': 11,' Assoc-voc': 12,
                                                ' Bachelors': 13,' Masters': 14,' Prof-school': 15,' Doctorate': 16})
# Out:
# 0         9
# 1         9
# 2        10
# 3         5
# 4        10
#          ..
# 31973     9
# 31974    10
# 31975    10
# 31976    10
# 31977    13
# Name: EdType, Length: 31978, dtype: object

# %%
inc.SalStat.unique()
# Out:
# array([' less than or equal to 50,000', ' greater than 50,000'],
#       dtype=object)

# %% [markdown]
# # Visualisation

# %%
import seaborn as sns
sns.displot(inc.SalStat,bins=20, edgecolor='black');

# %%
sns.countplot(x='SalStat', hue='gender', data=inc);

# %%
sns.displot(inc['age'], bins=15, kde=False);

# %%
sns.boxplot(x='SalStat', y='age', data=inc).set(title="Receiving salary based on Age");

# %%
sns.countplot(y='JobType', hue='SalStat', data=inc).set(title="Impact of JobType on Salary");

# %%
sns.countplot(y='EdType', hue='SalStat', data=inc).set(title="Impact of EdType on Salary");

# %%
sns.countplot(y='occupation', hue='SalStat', data=inc).set(title="Impact of Occupation on Salary");

# %%
sns.boxplot(x='SalStat', y='hoursperweek', data=inc).set(title="Impact of Hours Worked per week");

# %%
inc.SalStat.replace({' less than or equal to 50,000':0,' greater than 50,000':1},inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder     

le=LabelEncoder()

# %%
inc[inc.select_dtypes(include='object').columns]=inc[inc.select_dtypes(include='object').columns].apply(le.fit_transform)

# %% [markdown]
# # Outlier

# %%
import matplotlib.pyplot as plt

import seaborn as sns
plt.figure(figsize=(15,10))
sns.boxplot(data=inc)
# Out:
# <Axes: >

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
sns.heatmap(inc.corr().round(2),annot=True,cmap='coolwarm');

# %%
inc.head()
# Out:
#    age  JobType  EdType  maritalstatus  occupation  relationship  race  \
# 0   45        3      11              0           0             1     4
# 1   24        0      11              4           1             3     4
# 2   44        3      15              2           9             0     4
# 3   27        3       6              4           2             2     4
# 4   20        3      15              4          11             1     4
#
#    gender  capitalgain  capitalloss  hoursperweek  nativecountry  SalStat
# 0       0            0            0            28             38        0
# 1       1            0            0            40             38        0
# 2       1            0            0            40             38        1
# 3       1            0            0            40             25        0
# 4       1            0            0            35             38        0

# %%
inc.SalStat.value_counts()
# Out:
# 0    24283
# 1     7695
# Name: SalStat, dtype: int64

# %%
from sklearn.model_selection import train_test_split
inc_train,inc_test=train_test_split(inc,test_size=.2)

# %%
# over sampling
df7=inc_train[inc_train.SalStat==1]
inc_train=pd.concat([inc_train,df7,df7,df7])
inc_train.shape
# Out:
# (44041, 13)

# %%
inc.SalStat.value_counts()
# Out:
# 0    24283
# 1     7695
# Name: SalStat, dtype: int64

# %%
inc_train_x=inc_train.iloc[:,0:-1]
inc_train_y=inc_train.iloc[:,-1]


inc_test_x=inc_test.iloc[:,0:-1]
inc_test_y=inc_test.iloc[:,-1]

# %% [markdown]
# # Model Building

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
logreg=LogisticRegression()
logreg.fit(inc_train_x,inc_train_y)
# Out:
# LogisticRegression()

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
pred_train=logreg.predict(inc_train_x)
pred_test=logreg.predict(inc_test_x)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,f1_score,recall_score

# %%
mat_test=confusion_matrix(inc_test_y,pred_test)
mat_test
# Out:
# array([[3029, 1825],
#        [ 252, 1290]], dtype=int64)

# %%
accuracy_score(inc_test_y,pred_test)
# Out:
# 0.6752657911194496

# %%
recall_score(inc_test_y,pred_test)
# Out:
# 0.8365758754863813

# %%
precision_score(inc_test_y,pred_test)
# Out:
# 0.41412520064205455

# %%
f1_score(inc_test_y,pred_test)
# Out:
# 0.5540047240712905

# %%
fpr=1954/(1954+2918)
fpr*100
# Out:
# 40.106732348111656

# %%
from sklearn.metrics import roc_auc_score,roc_curve

# %%
pred_prob_test=logreg.predict_proba(inc_test_x)
len(pred_prob_test)
# Out:
# 6396

# %%
roc_auc_score(inc_test_y,pred_prob_test[:,1]) #area under the curve value
# Out:
# 0.8022428050835366

# %%
fpr,tpr,thre=roc_curve(inc_test_y,pred_prob_test[:,1])

# %%
plt.plot(fpr,tpr,marker='.',color='green')
plt.xlabel('Fpr')
plt.ylabel('Tpr')
plt.title("ROC plot on fpr and tpr")
plt.grid()

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dt1=DecisionTreeClassifier(criterion='gini',max_depth=8,min_samples_split=50)

# %%
dt1.fit(inc_train_x,inc_train_y)
# Out:
# DecisionTreeClassifier(max_depth=8, min_samples_split=50)

# %%
dt_pred=dt1.predict(inc_test_x)

# %%
confusion_matrix(inc_test_y,dt_pred)
# Out:
# array([[3546, 1308],
#        [ 168, 1374]], dtype=int64)

# %%
accuracy_score(inc_test_y,dt_pred)
# Out:
# 0.7692307692307693

# %%
precision_score(inc_test_y,dt_pred)
# Out:
# 0.5123042505592841

# %%
recall_score(inc_test_y,dt_pred)
# Out:
# 0.8910505836575876

# %%
f1_score(inc_test_y,dt_pred)
# Out:
# 0.6505681818181818

# %% [markdown]
# # GridSearch

# %%
from sklearn.model_selection import GridSearchCV

# %%
search_dict={"criterion":["gini","entropy"],
            "max_depth":range(4,9),
            "min_samples_split":[50,75,100]}
grid=GridSearchCV(dt1,param_grid=search_dict)
grid.fit(inc_train_x,inc_train_y)
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(max_depth=8,
#                                               min_samples_split=50),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': range(4, 9),
#                          'min_samples_split': [50, 75, 100]})

# %%
grid.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 8, 'min_samples_split': 50}

# %%
1394/(1394+3479)
# Out:
# 0.28606607839113485

# %%
pred_prob_test_dt1=dt1.predict_proba(inc_test_x)
len(pred_prob_test_dt1)
# Out:
# 6396

# %%
roc_auc_score(inc_test_y,pred_prob_test_dt1[:,1]) #area under the curve value
# Out:
# 0.8921168015254243

# %%
fpr,tpr,thre=roc_curve(inc_test_y,pred_prob_test_dt1[:,1])

# %%
plt.plot(fpr,tpr,marker='.',color='green')
plt.xlabel('Fpr')
plt.ylabel('Tpr')
plt.title("ROC plot on fpr and tpr")
plt.grid()

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier(criterion='gini',max_depth=8,min_samples_split=74,n_estimators=113)

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint
search_dict = {
    'n_estimators': randint(50, 150),
    'criterion': ['gini', 'entropy'],
    'max_depth': randint(4, 9),
    'min_samples_split': randint(50, 100)
}
rfc = RandomForestClassifier()
random_search = RandomizedSearchCV(rfc, param_distributions=search_dict, n_iter=10, cv=5)
random_search.fit(inc_train_x,inc_train_y)
print("Best Hyperparameters:", random_search.best_params_)
# Out:
# Best Hyperparameters: {'criterion': 'gini', 'max_depth': 8, 'min_samples_split': 56, 'n_estimators': 149}

# %%
rfc.fit(inc_train_x,inc_train_y)
# Out:
# RandomForestClassifier()

# %%
pred_rfc=rfc.predict(inc_test_x)

# %%
confusion_matrix(inc_test_y,pred_rfc)
# Out:
# array([[4243,  611],
#        [ 459, 1083]], dtype=int64)

# %%
accuracy_score(inc_test_y,pred_rfc)
# Out:
# 0.83270794246404

# %%
precision_score(inc_test_y,pred_rfc)
# Out:
# 0.6393152302243211

# %%
recall_score(inc_test_y,pred_rfc)
# Out:
# 0.7023346303501945

# %%
f1_score(inc_test_y,pred_rfc)
# Out:
# 0.669344870210136

# %%
1235/(3638+1235)
# Out:
# 0.25343730761337985

# %%
import seaborn as sns

# %%
sns.heatmap(confusion_matrix(inc_test_y,pred_rfc),annot=True,fmt='d',cmap='coolwarm').set_title('random_forest')
# Out:
# Text(0.5, 1.0, 'random_forest')

# %%
inc.race.value_counts()
# Out:
# 4    27430
# 2     3028
# 1      956
# 0      311
# 3      253
# Name: race, dtype: int64

# %%
rf_model = rfc.fit(inc_train_x,inc_train_y)
rf_model.feature_importances_
# Out:
# array([0.22548329, 0.0414879 , 0.09399279, 0.13665388, 0.08540904,
#        0.13099459, 0.01801111, 0.02223359, 0.08877628, 0.02995299,
#        0.10908981, 0.01791471])

# %%
#importances = pd.DataFrame(inc_train_x.columns,columns=['Features'])
#importances
importances=pd.DataFrame()
importances['Features']=inc_train_x.columns
importances
# Out:
#          Features
# 0             age
# 1         JobType
# 2          EdType
# 3   maritalstatus
# 4      occupation
# 5    relationship
# 6            race
# 7          gender
# 8     capitalgain
# 9     capitalloss
# 10   hoursperweek
# 11  nativecountry

# %%
#importances['Feature_importances'] = rf_model.feature_importances_
#importances
importances['Feature_importances']=rf_model.feature_importances_
importances
# Out:
#          Features  Feature_importances
# 0             age             0.225483
# 1         JobType             0.041488
# 2          EdType             0.093993
# 3   maritalstatus             0.136654
# 4      occupation             0.085409
# 5    relationship             0.130995
# 6            race             0.018011
# 7          gender             0.022234
# 8     capitalgain             0.088776
# 9     capitalloss             0.029953
# 10   hoursperweek             0.109090
# 11  nativecountry             0.017915

# %%
imp = importances.sort_values(by='Feature_importances',ascending=False)
imp
# Out:
#          Features  Feature_importances
# 0             age             0.225483
# 3   maritalstatus             0.136654
# 5    relationship             0.130995
# 10   hoursperweek             0.109090
# 2          EdType             0.093993
# 8     capitalgain             0.088776
# 4      occupation             0.085409
# 1         JobType             0.041488
# 9     capitalloss             0.029953
# 7          gender             0.022234
# 6            race             0.018011
# 11  nativecountry             0.017915

# %%
sns.barplot(y=imp['Features'],x=imp['Feature_importances'])
plt.show()

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVC
svc=SVC(kernel='sigmoid')

# %%
svc.fit(inc_train_x,inc_train_y)
# Out:
# SVC(kernel='sigmoid')

# %%
pred_svc=svc.predict(inc_test_x)

# %%
tab=confusion_matrix(inc_test_y,pred_svc)

# %%
tab
# Out:
# array([[4513,  341],
#        [1114,  428]], dtype=int64)

# %%
inc.shape
# Out:
# (31978, 13)

# %%
accuracy_score(inc_test_y,pred_svc)
# Out:
# 0.7725140712945591

# %%
precision_score(inc_test_y,pred_svc)
# Out:
# 0.5565669700910273

# %%
recall_score(inc_test_y,pred_svc)
# Out:
# 0.2775616083009079

# %%
f1_score(inc_test_y,pred_svc)
# Out:
# 0.37040242319342276

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(inc_test_y,pred_svc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.93      0.86      4854
#            1       0.56      0.28      0.37      1542
#
#     accuracy                           0.77      6396
#    macro avg       0.68      0.60      0.62      6396
# weighted avg       0.74      0.77      0.74      6396

# %%
FPR=363/(363+4479)*100
FPR
# Out:
# 7.496902106567534

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=25)

# %%
knn.fit(inc_train_x,inc_train_y)
# Out:
# KNeighborsClassifier(n_neighbors=25)

# %%
pred_knn=knn.predict(inc_test_x)

# %%
tab=confusion_matrix(inc_test_y,pred_knn)

# %%
tab
# Out:
# array([[3525, 1329],
#        [ 205, 1337]], dtype=int64)

# %%
accuracy_score(inc_test_y,pred_knn)
# Out:
# 0.7601626016260162

# %%
precision_score(inc_test_y,pred_knn)
# Out:
# 0.5015003750937734

# %%
recall_score(inc_test_y,pred_knn)
# Out:
# 0.8670557717250325

# %%
f1_score(inc_test_y,pred_knn)
# Out:
# 0.6354562737642585

# %%
print(classification_report(inc_test_y,pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.73      0.82      4854
#            1       0.50      0.87      0.64      1542
#
#     accuracy                           0.76      6396
#    macro avg       0.72      0.80      0.73      6396
# weighted avg       0.84      0.76      0.78      6396

# %%
#Compression of Models--------------->
l1=('Logistic regression','Decision Tree','Random Forest','Support Vector Mechine','K-Nearest Neighbour')
l2=(66,76,83,76,75)
l3=(40,50,65,54,49)
l4=(84,90,71,27,84)
l5=(54,64,67,36,62)
importances=pd.DataFrame()
importances['Models']=l1
importances['Accuracy']=l2
importances['precision_score']=l3
importances['recall_score']=l4
importances['f1_score']=l5
importances
# Out:
#                    Models  Accuracy  precision_score  recall_score  f1_score
# 0     Logistic regression        66               40            84        54
# 1           Decision Tree        76               50            90        64
# 2           Random Forest        83               65            71        67
# 3  Support Vector Mechine        76               54            27        36
# 4     K-Nearest Neighbour        75               49            84        62
